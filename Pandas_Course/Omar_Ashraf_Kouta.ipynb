# %%
import pandas as pd

df = pd.read_csv("database.csv")

# %%
print(pd.__version__)
# Out:
# 2.3.3

# %%
df.head()
# Out:
#          Date      Time  Latitude  Longitude        Type  Depth  Depth Error  \
# 0  01/02/1965  13:44:18    19.246    145.616  Earthquake  131.6          NaN
# 1  01/04/1965  11:29:49     1.863    127.352  Earthquake   80.0          NaN
# 2  01/05/1965  18:05:58   -20.579   -173.972  Earthquake   20.0          NaN
# 3  01/08/1965  18:49:43   -59.076    -23.557  Earthquake   15.0          NaN
# 4  01/09/1965  13:32:50    11.938    126.427  Earthquake   15.0          NaN
#
#    Depth Seismic Stations  Magnitude Magnitude Type  ...  \
# 0                     NaN        6.0             MW  ...
# 1                     NaN        5.8             MW  ...
# 2                     NaN        6.2             MW  ...
# 3                     NaN        5.8             MW  ...
# 4                     NaN        5.8             MW  ...
#
#    Magnitude Seismic Stations  Azimuthal Gap  Horizontal Distance  \
# 0                         NaN            NaN                  NaN
# ...

# %%
df.tail()
# Out:
#              Date      Time  Latitude  Longitude        Type  Depth  \
# 23407  12/28/2016  08:22:12   38.3917  -118.8941  Earthquake  12.30
# 23408  12/28/2016  09:13:47   38.3777  -118.8957  Earthquake   8.80
# 23409  12/28/2016  12:38:51   36.9179   140.4262  Earthquake  10.00
# 23410  12/29/2016  22:30:19   -9.0283   118.6639  Earthquake  79.00
# 23411  12/30/2016  20:08:28   37.3973   141.4103  Earthquake  11.94
#
#        Depth Error  Depth Seismic Stations  Magnitude Magnitude Type  ...  \
# 23407          1.2                    40.0        5.6             ML  ...
# 23408          2.0                    33.0        5.5             ML  ...
# 23409          1.8                     NaN        5.9            MWW  ...
# 23410          1.8                     NaN        6.3            MWW  ...
# 23411          2.2                     NaN        5.5             MB  ...
#
#        Magnitude Seismic Stations  Azimuthal Gap  Horizontal Distance  \
# ...

# %%
df.shape
# Out:
# (23412, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23412 entries, 0 to 23411
# Data columns (total 21 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Date                        23412 non-null  object
#  1   Time                        23412 non-null  object
#  2   Latitude                    23412 non-null  float64
#  3   Longitude                   23412 non-null  float64
#  4   Type                        23412 non-null  object
#  5   Depth                       23412 non-null  float64
#  6   Depth Error                 4461 non-null   float64
#  7   Depth Seismic Stations      7097 non-null   float64
#  8   Magnitude                   23412 non-null  float64
#  9   Magnitude Type              23409 non-null  object
#  10  Magnitude Error             327 non-null    float64
#  11  Magnitude Seismic Stations  2564 non-null   float64
#  12  Azimuthal Gap               7299 non-null   float64
# ...

# %%
df["Date"] = pd.to_datetime(df["Date"], format="%d/%m/%Y")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[60], line 1
# ----> 1 df["Date"] = pd.to_datetime(df["Date"], format="%d/%m/%Y")
#
# File ~/.local/lib/python3.12/site-packages/pandas/core/tools/datetimes.py:1068, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1066             result = arg.tz_localize("utc")
#    1067 elif isinstance(arg, ABCSeries):
# -> 1068     cache_array = _maybe_cache(arg, format, cache, convert_listlike)
#    1069     if not cache_array.empty:
#    1070         result = arg.map(cache_array)
#
# File ~/.local/lib/python3.12/site-packages/pandas/core/tools/datetimes.py:249, in _maybe_cache(arg, format, cache, convert_listlike)
#     247 unique_dates = unique(arg)
#     248 if len(unique_dates) < len(arg):
# --> 249     cache_dates = convert_listlike(unique_dates, format)
# ...

# %%
for k, v in df["Date"].items():
    if len(v) == 24:
        print(k, v)
# Out:
# 3378 1975-02-23T02:58:41.000Z
# 7512 1985-04-28T02:53:41.530Z
# 20650 2011-03-13T02:23:34.520Z

# %%
df["Date"] = df["Date"].str.split('T').str[0]

# %%
df.head()
# Out:
#          Date      Time  Latitude  Longitude        Type  Depth  Depth Error  \
# 0  01/02/1965  13:44:18    19.246    145.616  Earthquake  131.6          NaN
# 1  01/04/1965  11:29:49     1.863    127.352  Earthquake   80.0          NaN
# 2  01/05/1965  18:05:58   -20.579   -173.972  Earthquake   20.0          NaN
# 3  01/08/1965  18:49:43   -59.076    -23.557  Earthquake   15.0          NaN
# 4  01/09/1965  13:32:50    11.938    126.427  Earthquake   15.0          NaN
#
#    Depth Seismic Stations  Magnitude Magnitude Type  ...  \
# 0                     NaN        6.0             MW  ...
# 1                     NaN        5.8             MW  ...
# 2                     NaN        6.2             MW  ...
# 3                     NaN        5.8             MW  ...
# 4                     NaN        5.8             MW  ...
#
#    Magnitude Seismic Stations  Azimuthal Gap  Horizontal Distance  \
# 0                         NaN            NaN                  NaN
# ...

# %%
df["Date"] = pd.to_datetime(df["Date"], format="mixed")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23412 entries, 0 to 23411
# Data columns (total 21 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Date                        23412 non-null  datetime64[ns]
#  1   Time                        23412 non-null  object
#  2   Latitude                    23412 non-null  float64
#  3   Longitude                   23412 non-null  float64
#  4   Type                        23412 non-null  object
#  5   Depth                       23412 non-null  float64
#  6   Depth Error                 4461 non-null   float64
#  7   Depth Seismic Stations      7097 non-null   float64
#  8   Magnitude                   23412 non-null  float64
#  9   Magnitude Type              23409 non-null  object
#  10  Magnitude Error             327 non-null    float64
#  11  Magnitude Seismic Stations  2564 non-null   float64
#  12  Azimuthal Gap               7299 non-null   float64
# ...

# %%
df["Date"].iloc[3378].year
# Out:
# 1975

# %%
import matplotlib.pyplot as plt

plt.plot(df["Date"], df["Magnitude"])

# %%
plt.plot(df["Date"].dt.month, df["Magnitude"])

# %%
import seaborn as sns

sns.lineplot(
    data=df, 
    x="Month", 
    y="Magnitude",
    marker="o" 
)
plt.title('Mean Magnitude Trend Over the Months')
plt.xticks(range(1, 13))
plt.show()

# %%
df.groupby("Month")["Magnitude"].mean()
# Out:
# Month
# 1     5.874849
# 2     5.877037
# 3     5.874598
# 4     5.897260
# 5     5.890214
# 6     5.874271
# 7     5.885883
# 8     5.894374
# 9     5.873804
# 10    5.893207
# 11    5.885994
# 12    5.868406
# Name: Magnitude, dtype: float64

# %%
plt.plot(df.groupby("Month")["Magnitude"].mean())

# %%
plt.plot(df["Date"].dt.year, df["Magnitude"])

# %%
df["Month"] = df["Date"].dt.month
df.head()
# Out:
#         Date      Time  Latitude  Longitude        Type  Depth  Depth Error  \
# 0 1965-01-02  13:44:18    19.246    145.616  Earthquake  131.6          NaN
# 1 1965-01-04  11:29:49     1.863    127.352  Earthquake   80.0          NaN
# 2 1965-01-05  18:05:58   -20.579   -173.972  Earthquake   20.0          NaN
# 3 1965-01-08  18:49:43   -59.076    -23.557  Earthquake   15.0          NaN
# 4 1965-01-09  13:32:50    11.938    126.427  Earthquake   15.0          NaN
#
#    Depth Seismic Stations  Magnitude Magnitude Type  ...  Azimuthal Gap  \
# 0                     NaN        6.0             MW  ...            NaN
# 1                     NaN        5.8             MW  ...            NaN
# 2                     NaN        6.2             MW  ...            NaN
# 3                     NaN        5.8             MW  ...            NaN
# 4                     NaN        5.8             MW  ...            NaN
#
#    Horizontal Distance  Horizontal Error  Root Mean Square            ID  \
# ...
